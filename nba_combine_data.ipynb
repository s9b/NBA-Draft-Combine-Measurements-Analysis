# %% [markdown]
# <a href="https://colab.research.google.com/github/s9b/NBA-Draft-Combine-Measurements-Analysis/blob/main/nba_combine_data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install py_ball # install the missing module
import numpy as np
import pandas as pd


from py_ball import draft # now the module can be imported

HEADERS = {'Connection': 'keep-alive',
           'Host': 'stats.nba.com',
           'Origin': 'http://stats.nba.com',
           'Upgrade-Insecure-Requests': '1',
           'Referer': 'stats.nba.com',
           'x-nba-stats-origin': 'stats',
           'x-nba-stats-token': 'true',
           'Accept-Language': 'en-US,en;q=0.9',
           "X-NewRelic-ID": "VQECWF5UChAHUlNTBwgBVw==",
           'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64)' +\
                         ' AppleWebKit/537.36 (KHTML, like Gecko)' + \
                         ' Chrome/109.0.0.0 Safari/537.36'}

pd.options.mode.chained_assignment = None  # Disabling pandas SetWithCopyWarnings
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 106.4/106.4 kB 2.2 MB/s eta 0:00:00
# ...

# %%
league_id = '00' #NBA
season_year = ['2000-01']
draft_data = draft.Draft(headers=HEADERS,
                         endpoint='draftcombinestats',
                         league_id=league_id,
                         season_year=season_year)
draft_df1 = pd.DataFrame(draft_data.data['DraftCombineStats'])
draft_df1.head()
# Out:
#   SEASON  PLAYER_ID FIRST_NAME  LAST_NAME       PLAYER_NAME POSITION  \
# 0   2000       2124      Malik      Allen       Malik Allen     PF-C
# 1   2000      12019     Harold  Arceneaux  Harold Arceneaux    SG-SF
# 2   2000      12020     Lamont     Barnes     Lamont Barnes     PF-C
# 3   2000      12131      Mario      Bland       Mario Bland       PF
# 4   2000       2056     Primoz     Brezec     Primoz Brezec        C
#
#    HEIGHT_WO_SHOES HEIGHT_WO_SHOES_FT_IN HEIGHT_W_SHOES HEIGHT_W_SHOES_FT_IN  \
# 0            80.25             6' 8.25''           None                 None
# 1            76.50              6' 4.5''           None                 None
# 2            80.50              6' 8.5''           None                 None
# 3            77.50              6' 5.5''           None                 None
# 4            84.75             7' 0.75''           None                 None
#
#    ... STANDING_REACH_FT_IN  BODY_FAT_PCT HAND_LENGTH  HAND_WIDTH  \
# ...

# %%
league_id = '00' #NBA
season_year = ['2001-02']
draft_data = draft.Draft(headers=HEADERS,
                         endpoint='draftcombinestats',
                         league_id=league_id,
                         season_year=season_year)
draft_df2 = pd.DataFrame(draft_data.data['DraftCombineStats'])
draft_df2.head()
# Out:
#   SEASON  PLAYER_ID FIRST_NAME   LAST_NAME        PLAYER_NAME POSITION  \
# 0   2001      12033       Adam  Allenspach    Adam Allenspach        C
# 1   2001       2240    Gilbert      Arenas     Gilbert Arenas       SG
# 2   2001       2220    Brandon   Armstrong  Brandon Armstrong       SG
# 3   2001       2203      Shane     Battier      Shane Battier    SF-PF
# 4   2001      12034     Cookie     Belcher     Cookie Belcher    SG-PG
#
#    HEIGHT_WO_SHOES HEIGHT_WO_SHOES_FT_IN HEIGHT_W_SHOES HEIGHT_W_SHOES_FT_IN  \
# 0            83.50             6' 11.5''           None                 None
# 1            74.25             6' 2.25''           None                 None
# 2            75.50              6' 3.5''           None                 None
# 3            80.25             6' 8.25''           None                 None
# 4            75.00                6' 3''           None                 None
#
#    ... STANDING_REACH_FT_IN  BODY_FAT_PCT HAND_LENGTH  HAND_WIDTH  \
# ...

# %%
league_id = '00' #NBA
season_year = ['2002-03']
draft_data = draft.Draft(headers=HEADERS,
                         endpoint='draftcombinestats',
                         league_id=league_id,
                         season_year=season_year)
draft_df3 = pd.DataFrame(draft_data.data['DraftCombineStats'])
draft_df3.head()
# Out:
#   SEASON  PLAYER_ID FIRST_NAME  LAST_NAME       PLAYER_NAME POSITION  \
# 0   2002       2403       Nene                        Nene        PF
# 1   2002       2425     Robert  Archibald  Robert Archibald     PF-C
# 2   2002       2486    Maurice      Baker     Maurice Baker       PG
# 3   2002       2440       Matt     Barnes       Matt Barnes       SF
# 4   2002      12286      Lubos     Barton      Lubos Barton    SF-SG
#
#    HEIGHT_WO_SHOES HEIGHT_WO_SHOES_FT_IN HEIGHT_W_SHOES HEIGHT_W_SHOES_FT_IN  \
# 0            81.25             6' 9.25''           None                 None
# 1            82.00               6' 10''           None                 None
# 2            71.75            5' 11.75''           None                 None
# 3            78.75             6' 6.75''           None                 None
# 4            78.50              6' 6.5''           None                 None
#
#    ... STANDING_REACH_FT_IN  BODY_FAT_PCT HAND_LENGTH  HAND_WIDTH  \
# ...

# %%
league_id = '00' #NBA
season_year = ['2003-04']
draft_data = draft.Draft(headers=HEADERS,
                         endpoint='draftcombinestats',
                         league_id=league_id,
                         season_year=season_year)
draft_df4 = pd.DataFrame(draft_data.data['DraftCombineStats'])
draft_df4.head()
# Out:
#   SEASON  PLAYER_ID FIRST_NAME LAST_NAME        PLAYER_NAME POSITION  \
# 0   2003     200995   Aloysius  Anagonye  Aloysius Anagonye       PF
# 1   2003      12072       Rick  Anderson      Rick Anderson    SF-PF
# 2   2003       2546    Carmelo   Anthony    Carmelo Anthony       SF
# 3   2003       2602     Jerome   Beasley     Jerome Beasley    SF-PF
# 4   2003       2559       Troy      Bell          Troy Bell       PG
#
#    HEIGHT_WO_SHOES HEIGHT_WO_SHOES_FT_IN HEIGHT_W_SHOES HEIGHT_W_SHOES_FT_IN  \
# 0            78.75             6' 6.75''           None                 None
# 1            80.25             6' 8.25''           None                 None
# 2            78.25             6' 6.25''           None                 None
# 3            81.00                6' 9''           None                 None
# 4            72.25             6' 0.25''           None                 None
#
#    ... STANDING_REACH_FT_IN  BODY_FAT_PCT HAND_LENGTH  HAND_WIDTH  \
# ...

# %%
league_id = '00' #NBA
season_year = ['2004-05']
draft_data = draft.Draft(headers=HEADERS,
                         endpoint='draftcombinestats',
                         league_id=league_id,
                         season_year=season_year)
draft_df5 = pd.DataFrame(draft_data.data['DraftCombineStats'])
draft_df5.head()
# Out:
#   SEASON  PLAYER_ID FIRST_NAME LAST_NAME      PLAYER_NAME POSITION  \
# 0   2004       2754       Tony     Allen       Tony Allen       SG
# 1   2004       2772     Trevor     Ariza     Trevor Ariza    SG-SF
# 2   2004       2857      Andre   Barrett    Andre Barrett       PG
# 3   2004     101138    Brandon      Bass     Brandon Bass       PF
# 4   2004       2740     Andris  Biedrins  Andris Biedrins        C
#
#    HEIGHT_WO_SHOES HEIGHT_WO_SHOES_FT_IN  HEIGHT_W_SHOES HEIGHT_W_SHOES_FT_IN  \
# 0            75.50              6' 3.5''           76.25            6' 4.25''
# 1            79.00                6' 7''           80.25            6' 8.25''
# 2            68.75             5' 8.75''           69.75            5' 9.75''
# 3            78.25             6' 6.25''           79.25            6' 7.25''
# 4              NaN                  None             NaN                 None
#
#    ... STANDING_REACH_FT_IN  BODY_FAT_PCT HAND_LENGTH  HAND_WIDTH  \
# ...

# %%
league_id = '00' #NBA
season_year = ['2005-06']
draft_data = draft.Draft(headers=HEADERS,
                         endpoint='draftcombinestats',
                         league_id=league_id,
                         season_year=season_year)
draft_df6 = pd.DataFrame(draft_data.data['DraftCombineStats'])
draft_df6.head()
# Out:
#   SEASON  PLAYER_ID FIRST_NAME    LAST_NAME          PLAYER_NAME POSITION  \
# 0   2005     101165       Alex        Acker           Alex Acker       SG
# 1   2005     101224       Deji     Akindele        Deji Akindele     C-PF
# 2   2005     200969    Mustafa    Al-Sayyad    Mustafa Al-Sayyad     PF-C
# 3   2005      12104    Nemanja  Aleksandrov  Nemanja Aleksandrov    PF-SF
# 4   2005     101187       Alan     Anderson        Alan Anderson    SG-SF
#
#    HEIGHT_WO_SHOES HEIGHT_WO_SHOES_FT_IN  HEIGHT_W_SHOES HEIGHT_W_SHOES_FT_IN  \
# 0            75.75             6' 3.75''           76.75            6' 4.75''
# 1            81.50              6' 9.5''           83.00              6' 11''
# 2              NaN                  None             NaN                 None
# 3            82.00               6' 10''           84.00               7' 0''
# 4            76.50              6' 4.5''           78.00               6' 6''
#
# ...

# %%
league_id = '00' #NBA
season_year = ['2006-07']
draft_data = draft.Draft(headers=HEADERS,
                         endpoint='draftcombinestats',
                         league_id=league_id,
                         season_year=season_year)
draft_df7 = pd.DataFrame(draft_data.data['DraftCombineStats'])
draft_df7.head()
# Out:
#   SEASON  PLAYER_ID FIRST_NAME LAST_NAME        PLAYER_NAME POSITION  \
# 0   2006      12123      Kenny   Adeleke      Kenny Adeleke     PF-C
# 1   2006     200772    Maurice      Ager       Maurice Ager    SG-PG
# 2   2006     200746   LaMarcus  Aldridge  LaMarcus Aldridge     PF-C
# 3   2006     201165     Morris    Almond      Morris Almond    SG-SF
# 4   2006     200811        Lou  Amundson       Lou Amundson       PF
#
#    HEIGHT_WO_SHOES HEIGHT_WO_SHOES_FT_IN  HEIGHT_W_SHOES HEIGHT_W_SHOES_FT_IN  \
# 0            78.50              6' 6.5''           79.75            6' 7.75''
# 1            75.25             6' 3.25''           76.50             6' 4.5''
# 2            82.00               6' 10''           83.25           6' 11.25''
# 3            76.75             6' 4.75''           78.00               6' 6''
# 4            79.20              6' 7.2''           80.00               6' 8''
#
#    ... STANDING_REACH_FT_IN  BODY_FAT_PCT HAND_LENGTH  HAND_WIDTH  \
# ...

# %%
league_id = '00' #NBA
season_year = ['2007-08']
draft_data = draft.Draft(headers=HEADERS,
                         endpoint='draftcombinestats',
                         league_id=league_id,
                         season_year=season_year)
draft_df8 = pd.DataFrame(draft_data.data['DraftCombineStats'])
draft_df8.head()
# Out:
#   SEASON  PLAYER_ID FIRST_NAME LAST_NAME     PLAYER_NAME POSITION  \
# 0   2007      12204    Mohamed    Abukar  Mohamed Abukar       SF
# 1   2007      12205      Mario    Boggan    Mario Boggan       PF
# 2   2007      12206      Craig  Bradshaw  Craig Bradshaw       PF
# 3   2007     201147      Corey    Brewer    Corey Brewer    SF-SG
# 4   2007     201166      Aaron    Brooks    Aaron Brooks       PG
#
#    HEIGHT_WO_SHOES HEIGHT_WO_SHOES_FT_IN  HEIGHT_W_SHOES HEIGHT_W_SHOES_FT_IN  \
# 0             80.0                6' 8''           81.75            6' 9.75''
# 1             77.0                6' 5''           79.00               6' 7''
# 2             80.0                6' 8''           81.75            6' 9.75''
# 3             78.0                6' 6''           79.75            6' 7.75''
# 4             70.0               5' 10''           71.75           5' 11.75''
#
#    ... STANDING_REACH_FT_IN  BODY_FAT_PCT HAND_LENGTH  HAND_WIDTH  \
# ...

# %%
league_id = '00' #NBA
season_year = ['2008-09']
draft_data = draft.Draft(headers=HEADERS,
                         endpoint='draftcombinestats',
                         league_id=league_id,
                         season_year=season_year)
draft_df9 = pd.DataFrame(draft_data.data['DraftCombineStats'])
draft_df9.head()
# Out:
#   SEASON  PLAYER_ID FIRST_NAME  LAST_NAME      PLAYER_NAME POSITION  \
# 0   2008     201570        Joe  Alexander    Joe Alexander    SF-PF
# 1   2008     201589    Darrell     Arthur   Darrell Arthur       PF
# 2   2008     201571       D.J.   Augustin    D.J. Augustin       PG
# 3   2008     201573     Jerryd    Bayless   Jerryd Bayless    PG-SG
# 4   2008     201563    Michael    Beasley  Michael Beasley    PF-SF
#
#    HEIGHT_WO_SHOES HEIGHT_WO_SHOES_FT_IN  HEIGHT_W_SHOES HEIGHT_W_SHOES_FT_IN  \
# 0            79.25             6' 7.25''           80.25            6' 8.25''
# 1            79.50              6' 7.5''           80.50             6' 8.5''
# 2            70.00               5' 10''           71.50            5' 11.5''
# 3            73.75             6' 1.75''           75.00               6' 3''
# 4            79.00                6' 7''           80.25            6' 8.25''
#
#    ... STANDING_REACH_FT_IN  BODY_FAT_PCT HAND_LENGTH  HAND_WIDTH  \
# ...

# %%
league_id = '00' #NBA
season_year = ['2009-10']
draft_data = draft.Draft(headers=HEADERS,
                         endpoint='draftcombinestats',
                         league_id=league_id,
                         season_year=season_year)
draft_df10 = pd.DataFrame(draft_data.data['DraftCombineStats'])
draft_df10.head()
# Out:
#   SEASON  PLAYER_ID FIRST_NAME LAST_NAME        PLAYER_NAME POSITION  \
# 0   2009     202399       Jeff    Adrien        Jeff Adrien       PF
# 1   2009     201965       Jeff     Ayres         Jeff Ayres       PF
# 2   2009     201958   Rodrigue  Beaubois  Rodrigue Beaubois       PG
# 3   2009     201971     DeJuan     Blair       DeJuan Blair       PF
# 4   2009     201974    Derrick     Brown      Derrick Brown    SF-PF
#
#    HEIGHT_WO_SHOES HEIGHT_WO_SHOES_FT_IN  HEIGHT_W_SHOES HEIGHT_W_SHOES_FT_IN  \
# 0            77.25             6' 5.25''           78.50             6' 6.5''
# 1            80.75             6' 8.75''           82.00              6' 10''
# 2            73.25             6' 1.25''           74.25            6' 2.25''
# 3            77.25             6' 5.25''           78.50             6' 6.5''
# 4            79.50              6' 7.5''           80.50             6' 8.5''
#
#    ... STANDING_REACH_FT_IN  BODY_FAT_PCT HAND_LENGTH  HAND_WIDTH  \
# ...

# %%
league_id = '00' #NBA
season_year = ['2010-11']
draft_data = draft.Draft(headers=HEADERS,
                         endpoint='draftcombinestats',
                         league_id=league_id,
                         season_year=season_year)
draft_df11 = pd.DataFrame(draft_data.data['DraftCombineStats'])
draft_df11.head()
# Out:
#   SEASON  PLAYER_ID FIRST_NAME LAST_NAME      PLAYER_NAME POSITION  \
# 0   2010     202374    Solomon     Alabi    Solomon Alabi        C
# 1   2010     202332       Cole   Aldrich     Cole Aldrich        C
# 2   2010     202329  Al-Farouq     Aminu  Al-Farouq Aminu       SF
# 3   2010     202341      James  Anderson   James Anderson       SF
# 4   2010     202337       Luke   Babbitt     Luke Babbitt    SF-PF
#
#    HEIGHT_WO_SHOES HEIGHT_WO_SHOES_FT_IN  HEIGHT_W_SHOES HEIGHT_W_SHOES_FT_IN  \
# 0            83.50             6' 11.5''           84.75            7' 0.75''
# 1            81.00                6' 9''           83.25           6' 11.25''
# 2            79.25             6' 7.25''           80.50             6' 8.5''
# 3            76.75             6' 4.75''           77.75            6' 5.75''
# 4            79.50              6' 7.5''           80.75            6' 8.75''
#
#    ... STANDING_REACH_FT_IN  BODY_FAT_PCT HAND_LENGTH  HAND_WIDTH  \
# ...

# %%
league_id = '00' #NBA
season_year = ['2011-12']
draft_data = draft.Draft(headers=HEADERS,
                         endpoint='draftcombinestats',
                         league_id=league_id,
                         season_year=season_year)
draft_df12 = pd.DataFrame(draft_data.data['DraftCombineStats'])
draft_df12.head()
# Out:
#   SEASON  PLAYER_ID FIRST_NAME LAST_NAME     PLAYER_NAME POSITION  \
# 0   2011     202728      Keith    Benson    Keith Benson     C-PF
# 1   2011     202705    Marshon    Brooks  Marshon Brooks       SG
# 2   2011     202692       Alec     Burks      Alec Burks       SG
# 3   2011     202710      Jimmy    Butler    Jimmy Butler       SF
# 4   2011     202708     Norris      Cole     Norris Cole       PG
#
#    HEIGHT_WO_SHOES HEIGHT_WO_SHOES_FT_IN  HEIGHT_W_SHOES HEIGHT_W_SHOES_FT_IN  \
# 0            82.00               6' 10''           83.00              6' 11''
# 1            76.25             6' 4.25''           77.25            6' 5.25''
# 2            77.00                6' 5''           78.00               6' 6''
# 3            78.00                6' 6''           79.75            6' 7.75''
# 4            72.25             6' 0.25''           73.75            6' 1.75''
#
#    ... STANDING_REACH_FT_IN  BODY_FAT_PCT HAND_LENGTH  HAND_WIDTH  \
# ...

# %%
league_id = '00' #NBA
season_year = ['2012-13']
draft_data = draft.Draft(headers=HEADERS,
                         endpoint='draftcombinestats',
                         league_id=league_id,
                         season_year=season_year)
draft_df13 = pd.DataFrame(draft_data.data['DraftCombineStats'])
draft_df13.head()
# Out:
#   SEASON  PLAYER_ID FIRST_NAME LAST_NAME      PLAYER_NAME POSITION  \
# 0   2012     203112     Quincy       Acy       Quincy Acy       PF
# 1   2012     203084   Harrison    Barnes  Harrison Barnes    SF-SG
# 2   2012     203115       Will    Barton      Will Barton    SG-SF
# 3   2012     203078    Bradley      Beal     Bradley Beal       SG
# 4   2012      12458    J'Covan     Brown    J'Covan Brown       PG
#
#    HEIGHT_WO_SHOES HEIGHT_WO_SHOES_FT_IN  HEIGHT_W_SHOES HEIGHT_W_SHOES_FT_IN  \
# 0            78.50              6' 6.5''           79.75            6' 7.75''
# 1            79.00                6' 7''           80.00               6' 8''
# 2            77.00                6' 5''           78.00               6' 6''
# 3            75.25             6' 3.25''           76.75            6' 4.75''
# 4            73.00                6' 1''           74.25            6' 2.25''
#
#    ... STANDING_REACH_FT_IN  BODY_FAT_PCT HAND_LENGTH  HAND_WIDTH  \
# ...

# %%
league_id = '00' #NBA
season_year = ['2013-14']
draft_data = draft.Draft(headers=HEADERS,
                         endpoint='draftcombinestats',
                         league_id=league_id,
                         season_year=season_year)
draft_df14 = pd.DataFrame(draft_data.data['DraftCombineStats'])
draft_df14.head()
# Out:
#   SEASON  PLAYER_ID FIRST_NAME LAST_NAME     PLAYER_NAME POSITION  \
# 0   2013     203500     Steven     Adams    Steven Adams        C
# 1   2013     203505     Vander      Blue     Vander Blue       SG
# 2   2013     203485    Lorenzo     Brown   Lorenzo Brown       PG
# 3   2013     203493     Reggie   Bullock  Reggie Bullock    SG-SF
# 4   2013     203504       Trey     Burke      Trey Burke       PG
#
#    HEIGHT_WO_SHOES HEIGHT_WO_SHOES_FT_IN  HEIGHT_W_SHOES HEIGHT_W_SHOES_FT_IN  \
# 0            82.75            6' 10.75''           84.00               7' 0''
# 1            75.50              6' 3.5''           77.25            6' 5.25''
# 2            76.00                6' 4''           77.25            6' 5.25''
# 3            77.75             6' 5.75''           79.00               6' 7''
# 4            71.75            5' 11.75''           73.25            6' 1.25''
#
#    ... SPOT_COLLEGE_CORNER_LEFT  SPOT_COLLEGE_BREAK_LEFT SPOT_COLLEGE_TOP_KEY  \
# ...

# %%
league_id = '00' #NBA
season_year = ['2014-15']
draft_data = draft.Draft(headers=HEADERS,
                         endpoint='draftcombinestats',
                         league_id=league_id,
                         season_year=season_year)
draft_df15 = pd.DataFrame(draft_data.data['DraftCombineStats'])
draft_df15.head()
# Out:
#   SEASON  PLAYER_ID FIRST_NAME      LAST_NAME             PLAYER_NAME  \
# 0   2014     203919     Jordan          Adams            Jordan Adams
# 1   2014     203937       Kyle       Anderson           Kyle Anderson
# 2   2014     203648   Thanasis  Antetokounmpo  Thanasis Antetokounmpo
# 3   2014     203947     Jordan      Bachynski        Jordan Bachynski
# 4   2014     203946    Cameron       Bairstow        Cameron Bairstow
#
#   POSITION  HEIGHT_WO_SHOES HEIGHT_WO_SHOES_FT_IN  HEIGHT_W_SHOES  \
# 0       SG            75.50              6' 3.5''           76.75
# 1       SF            79.50              6' 7.5''           80.50
# 2       SF            77.25             6' 5.25''           78.25
# 3       PF            85.25             7' 1.25''           86.00
# 4       PF            80.75             6' 8.75''           81.75
#
#   HEIGHT_W_SHOES_FT_IN  ... SPOT_NBA_BREAK_RIGHT  SPOT_NBA_CORNER_RIGHT  \
# ...

# %%
league_id = '00' #NBA
season_year = ['2015-16']
draft_data = draft.Draft(headers=HEADERS,
                         endpoint='draftcombinestats',
                         league_id=league_id,
                         season_year=season_year)
draft_df16 = pd.DataFrame(draft_data.data['DraftCombineStats'])
draft_df16.head()
# Out:
#   SEASON  PLAYER_ID FIRST_NAME  LAST_NAME      PLAYER_NAME POSITION  \
# 0   2015    1626146      Cliff  Alexander  Cliff Alexander     PF-C
# 1   2015    1626147     Justin   Anderson  Justin Anderson    SF-SG
# 2   2015    1626165    Brandon     Ashley   Brandon Ashley       PF
# 3   2015    1626207       Ryan  Boatright   Ryan Boatright       PG
# 4   2015    1626164      Devin     Booker     Devin Booker       SG
#
#    HEIGHT_WO_SHOES HEIGHT_WO_SHOES_FT_IN  HEIGHT_W_SHOES HEIGHT_W_SHOES_FT_IN  \
# 0            79.25             6' 7.25''           80.50             6' 8.5''
# 1            77.25             6' 5.25''           78.25            6' 6.25''
# 2            79.25             6' 7.25''           80.50             6' 8.5''
# 3            70.00               5' 10''           71.00              5' 11''
# 4            76.50              6' 4.5''           77.75            6' 5.75''
#
#    ... SPOT_NBA_BREAK_RIGHT  SPOT_NBA_CORNER_RIGHT  \
# ...

# %%
league_id = '00' #NBA
season_year = ['2016-17']
draft_data = draft.Draft(headers=HEADERS,
                         endpoint='draftcombinestats',
                         league_id=league_id,
                         season_year=season_year)
draft_df17 = pd.DataFrame(draft_data.data['DraftCombineStats'])
draft_df17.head()
# Out:
#   SEASON  PLAYER_ID FIRST_NAME   LAST_NAME      PLAYER_NAME POSITION  \
# 0   2016    1627758        Ron       Baker        Ron Baker       SG
# 1   2016    1627735       Wade  Baldwin IV  Wade Baldwin IV       PG
# 2   2016    1627760        Cat      Barber       Cat Barber       PG
# 3   2016    1627736      Malik     Beasley    Malik Beasley       SG
# 4   2016    1627761    DeAndre      Bembry   DeAndre Bembry    SG-SF
#
#    HEIGHT_WO_SHOES HEIGHT_WO_SHOES_FT_IN  HEIGHT_W_SHOES HEIGHT_W_SHOES_FT_IN  \
# 0            75.25             6' 3.25''           76.25            6' 4.25''
# 1            74.50              6' 2.5''           76.00               6' 4''
# 2            73.50              6' 1.5''           74.75            6' 2.75''
# 3            75.50              6' 3.5''           76.50             6' 4.5''
# 4            76.25             6' 4.25''           77.75            6' 5.75''
#
#    ... SPOT_NBA_BREAK_RIGHT  SPOT_NBA_CORNER_RIGHT  \
# ...

# %%
league_id = '00' #NBA
season_year = ['2017-18']
draft_data = draft.Draft(headers=HEADERS,
                         endpoint='draftcombinestats',
                         league_id=league_id,
                         season_year=season_year)
draft_df18 = pd.DataFrame(draft_data.data['DraftCombineStats'])
draft_df18.head()
# Out:
#   SEASON  PLAYER_ID FIRST_NAME LAST_NAME     PLAYER_NAME POSITION  \
# 0   2017    1628389     Edrice   Adebayo  Edrice Adebayo     PF-C
# 1   2017    1628959      Rawle    Alkins    Rawle Alkins    SG-SF
# 2   2017    1628386    Jarrett     Allen   Jarrett Allen        C
# 3   2017    1628443     Kadeem     Allen    Kadeem Allen       PG
# 4   2017    1628387        Ike  Anigbogu    Ike Anigbogu        C
#
#    HEIGHT_WO_SHOES HEIGHT_WO_SHOES_FT_IN  HEIGHT_W_SHOES HEIGHT_W_SHOES_FT_IN  \
# 0            80.75             6' 8.75''           75.75            6' 9.75''
# 1            74.50              6' 2.5''           75.75            6' 3.75''
# 2            81.00                6' 9''           82.25           6' 10.25''
# 3            73.00                6' 1''           74.25            6' 2.25''
# 4            80.50              6' 8.5''           81.75            6' 9.75''
#
#    ... SPOT_NBA_BREAK_RIGHT  SPOT_NBA_CORNER_RIGHT  \
# ...

# %%
league_id = '00' #NBA
season_year = ['2018-19']
draft_data = draft.Draft(headers=HEADERS,
                         endpoint='draftcombinestats',
                         league_id=league_id,
                         season_year=season_year)
draft_df19 = pd.DataFrame(draft_data.data['DraftCombineStats'])
draft_df19.head()
# Out:
#   SEASON  PLAYER_ID FIRST_NAME      LAST_NAME           PLAYER_NAME POSITION  \
# 0   2018    1628959      Rawle         Alkins          Rawle Alkins       SG
# 1   2018    1628960    Grayson          Allen         Grayson Allen       SG
# 2   2018    1628961     Kostas  Antetokounmpo  Kostas Antetokounmpo       PF
# 3   2018    1628962      Udoka       Azubuike        Udoka Azubuike        C
# 4   2018    1628964    Mohamed          Bamba         Mohamed Bamba        C
#
#    HEIGHT_WO_SHOES HEIGHT_WO_SHOES_FT_IN  HEIGHT_W_SHOES HEIGHT_W_SHOES_FT_IN  \
# 0            74.75             6' 2.75''           76.25            6' 4.25''
# 1            75.00                6' 3''           76.50             6' 4.5''
# 2            81.00                6' 9''           82.50            6' 10.5''
# 3            82.00               6' 10''           84.25            7' 0.25''
# 4            83.25            6' 11.25''           84.75            7' 0.75''
#
# ...

# %%
league_id = '00' #NBA
season_year = ['2019-20']
draft_data = draft.Draft(headers=HEADERS,
                         endpoint='draftcombinestats',
                         league_id=league_id,
                         season_year=season_year)
draft_df20 = pd.DataFrame(draft_data.data['DraftCombineStats'])
draft_df20.head()
# Out:
#   SEASON  PLAYER_ID FIRST_NAME         LAST_NAME               PLAYER_NAME  \
# 0   2019    1629638    Nickeil  Alexander-Walker  Nickeil Alexander-Walker
# 1   2019    1629628         RJ           Barrett                RJ Barrett
# 2   2019    1629646    Charles            Bassey            Charles Bassey
# 3   2019    1629647     Darius            Bazley             Darius Bazley
# 4   2019    1629626        Bol               Bol                   Bol Bol
#
#   POSITION  HEIGHT_WO_SHOES HEIGHT_WO_SHOES_FT_IN  HEIGHT_W_SHOES  \
# 0       SG            76.25             6' 4.25''            77.5
# 1       SF              NaN                  None             NaN
# 2        C            80.75             6' 8.75''            82.0
# 3       PF            79.75             6' 7.75''            81.0
# 4        C            84.75             7' 0.75''            86.5
#
#   HEIGHT_W_SHOES_FT_IN  ... SPOT_NBA_BREAK_RIGHT  SPOT_NBA_CORNER_RIGHT  \
# ...

# %%
league_id = '00' #NBA
season_year = ['2020-21']
draft_data = draft.Draft(headers=HEADERS,
                         endpoint='draftcombinestats',
                         league_id=league_id,
                         season_year=season_year)
draft_df21 = pd.DataFrame(draft_data.data['DraftCombineStats'])
draft_df21.head()
# Out:
#   SEASON  PLAYER_ID FIRST_NAME  LAST_NAME        PLAYER_NAME POSITION  \
# 0   2020    1630173   Precious    Achiuwa   Precious Achiuwa       PF
# 1   2020    1630234    Ty-Shon  Alexander  Ty-Shon Alexander       SG
# 2   2020    1628962      Udoka   Azubuike     Udoka Azubuike        C
# 3   2020    1630189      Tyler        Bey          Tyler Bey       PF
# 4   2020    1630213      Yoeli     Childs       Yoeli Childs       PF
#
#    HEIGHT_WO_SHOES HEIGHT_WO_SHOES_FT_IN  HEIGHT_W_SHOES HEIGHT_W_SHOES_FT_IN  \
# 0             79.5              6'7.50''            80.7             6'8.75''
# 1             74.0              6'2.00''            76.0             6'4.00''
# 2             82.0             6'10.00''            83.5            6'11.50''
# 3             78.0              6'6.00''            79.0             6'7.00''
# 4             78.0              6'6.00''            79.0             6'7.00''
#
#    ... SPOT_NBA_BREAK_RIGHT  SPOT_NBA_CORNER_RIGHT  \
# ...

# %%
league_id = '00' #NBA
season_year = ['2021-22']
draft_data = draft.Draft(headers=HEADERS,
                         endpoint='draftcombinestats',
                         league_id=league_id,
                         season_year=season_year)
draft_df22 = pd.DataFrame(draft_data.data['DraftCombineStats'])
draft_df22.head()
# Out:
#   SEASON  PLAYER_ID FIRST_NAME LAST_NAME     PLAYER_NAME POSITION  \
# 0   2021    1630546        Max     Abmas       Max Abmas       PG
# 1   2021    1630534      Ochai    Agbaji    Ochai Agbaji       SG
# 2   2021    1630542     Marcus    Bagley   Marcus Bagley       SF
# 3   2021    1630567    Scottie    Barnes  Scottie Barnes       SF
# 4   2021    1629646    Charles    Bassey  Charles Bassey        C
#
#    HEIGHT_WO_SHOES HEIGHT_WO_SHOES_FT_IN  HEIGHT_W_SHOES HEIGHT_W_SHOES_FT_IN  \
# 0            70.50              5'10.5''           71.75            5'11.75''
# 1            76.50               6'4.5''           77.50              6'5.5''
# 2            78.00               6'6.0''           79.75             6'7.75''
# 3            79.00               6'7.0''           80.00              6'8.0''
# 4            81.25              6'9.25''           82.25            6'10.25''
#
#    ... SPOT_NBA_BREAK_RIGHT  SPOT_NBA_CORNER_RIGHT  \
# ...

# %%
league_id = '00' #NBA
season_year = ['2022-23']
draft_data = draft.Draft(headers=HEADERS,
                         endpoint='draftcombinestats',
                         league_id=league_id,
                         season_year=season_year)
draft_df23 = pd.DataFrame(draft_data.data['DraftCombineStats'])
draft_df23.head()
# Out:
#   SEASON  PLAYER_ID FIRST_NAME    LAST_NAME          PLAYER_NAME POSITION  \
# 0   2022    1630534      Ochai       Agbaji         Ochai Agbaji       SG
# 1   2022    1631116    Patrick  Baldwin Jr.  Patrick Baldwin Jr.       SF
# 2   2022    1631094      Paolo     Banchero       Paolo Banchero       PF
# 3   2022    1631230   Dominick       Barlow      Dominick Barlow       PF
# 4   2022    1630699     MarJon    Beauchamp     MarJon Beauchamp       SG
#
#    HEIGHT_WO_SHOES HEIGHT_WO_SHOES_FT_IN  HEIGHT_W_SHOES HEIGHT_W_SHOES_FT_IN  \
# 0            76.50             6' 4.50''           77.75            6' 5.75''
# 1            81.25             6' 9.25''           82.25           6' 10.25''
# 2              NaN                  None             NaN                 None
# 3            80.75             6' 8.75''           81.75            6' 9.75''
# 4            77.25             6' 5.25''           78.50            6' 6.50''
#
# ...

# %%
# Grabbing all created dataframes and combining them into one

frames = [draft_df1, draft_df2, draft_df3, draft_df4, draft_df5, draft_df6, draft_df7, draft_df8, draft_df9, draft_df10,
         draft_df11, draft_df12, draft_df13, draft_df14, draft_df15, draft_df16, draft_df17, draft_df18, draft_df19,
         draft_df20, draft_df21, draft_df22, draft_df23]
draft_df = pd.concat(frames)
# Out:
# <ipython-input-35-8c44dbde619a>:6: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   draft_df = pd.concat(frames)

# %%
draft_df.head()
# Out:
#   SEASON  PLAYER_ID FIRST_NAME  LAST_NAME       PLAYER_NAME POSITION  \
# 0   2000       2124      Malik      Allen       Malik Allen     PF-C
# 1   2000      12019     Harold  Arceneaux  Harold Arceneaux    SG-SF
# 2   2000      12020     Lamont     Barnes     Lamont Barnes     PF-C
# 3   2000      12131      Mario      Bland       Mario Bland       PF
# 4   2000       2056     Primoz     Brezec     Primoz Brezec        C
#
#    HEIGHT_WO_SHOES HEIGHT_WO_SHOES_FT_IN  HEIGHT_W_SHOES HEIGHT_W_SHOES_FT_IN  \
# 0            80.25             6' 8.25''             NaN                 None
# 1            76.50              6' 4.5''             NaN                 None
# 2            80.50              6' 8.5''             NaN                 None
# 3            77.50              6' 5.5''             NaN                 None
# 4            84.75             7' 0.75''             NaN                 None
#
#    ... SPOT_NBA_BREAK_RIGHT  SPOT_NBA_CORNER_RIGHT  \
# ...

# %%
draft_df.shape
# Out:
# (1551, 47)

# %%
draft_df['SEASON'].unique()
# Out:
# array(['2000', '2001', '2004', '2003', '2005', '2006', '2007', '2008',
#        '2009', '2010', '2011', '2012', '2013', '2014', '2015', '2016',
#        '2017', '2018', '2019', '2020', '2021', '2022'], dtype=object)

# %%
import os
# Check if the directory exists
if not os.path.exists("data"):
    # If it doesn't exist, create it
    os.makedirs("data")

# Now you can save the DataFrame to the CSV file
draft_df.to_csv("./data/nba_draft_data.csv", index=False)
